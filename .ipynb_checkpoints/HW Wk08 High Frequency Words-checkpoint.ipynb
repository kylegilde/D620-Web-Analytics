# %% [markdown]
# # Homework Week 8: High Frequency Words
#
# ## Data 620 Web Analytics
#
# ### Kyle Gilde
#
# ### 10/17/18
#
# #### Instructions
#
# Please answer the following questions in an IPython Notebook, posted to GitHub.
#
# 1. Choose a corpus of interest.
#
# For this exercise, let's use the Wall Street Journal corpus.

# %%
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#nltk.download() # C:\Users\kyleg\AppData\Roaming\nltk_data
from nltk.book import text7
text7
# Out:
# <Text: Wall Street Journal>

# %%
[token for token in text7[:10]]
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the']

# %% [markdown]
# 2. How many total unique words are in the corpus? (Please feel free to define unique words in any interesting, defensible way).
#
# First, let's normalize the corpus by doing the following:
#
# - stemming using the Porter stemmer
#
# - changing the letters to lowercase
#
# - only selecting tokens with alphabetical characters
#
# This normalization nearly cuts the number of unique tokens in half.

# %%
print(len(set(text7)))
stemmer = nltk.PorterStemmer()
wsj_stemmed = [stemmer.stem(t).lower() for t in text7 if t.isalpha()]
print(len(set(wsj_stemmed)))
wsj_stemmed[:10]
# Out:
# 12408
# 6300
# ['pierr', 'vinken', 'year', 'old', 'will', 'join', 'the', 'board', 'as', 'a']

# %% [markdown]
# 3. Taking the most common words, how many unique words represent half of the total words in the corpus?
#
# The 123 most common words account for 50% of all words in the corpus.

# %%
fdist = FreqDist(wsj_stemmed)
fdist_df = pd.DataFrame(list(dict(fdist).items()), columns=['word', 'n'])
fdist_df['proportion'] = fdist_df.n / fdist_df.n.sum()

fdist_df = fdist_df.sort_values('n', ascending=False).reset_index().drop('index', axis=1)
fdist_df['cumulative'] = fdist_df.proportion.cumsum()
fdist_df[fdist_df.cumulative <= .5].shape[0]
# Out:
# 123

# %% [markdown]
# 4. Identify the 200 highest frequency words in this corpus.

# %%
top200 = fdist_df[:200]
top200
# Out:
#          word     n  proportion  cumulative
# 0         the  4764    0.063364    0.063364
# 1          of  2325    0.030924    0.094287
# 2          to  2182    0.029022    0.123309
# 3           a  1988    0.026441    0.149751
# 4          in  1770    0.023542    0.173293
# 5         and  1556    0.020696    0.193988
# 6          it   920    0.012236    0.206225
# 7         for   853    0.011345    0.217570
# 8        that   848    0.011279    0.228849
# 9          is   672    0.008938    0.237787
# 10       said   628    0.008353    0.246140
# 11         on   508    0.006757    0.252896
# 12         by   440    0.005852    0.258748
# 13         at   430    0.005719    0.264468
# 14         as   415    0.005520    0.269987
# 15       with   398    0.005294    0.275281
# 16       from   391    0.005201    0.280481
# 17         be   390    0.005187    0.285669
# 18    million   389    0.005174    0.290843
# 19         wa   370    0.004921    0.295764
# 20        are   369    0.004908    0.300672
# 21         ha   339    0.004509    0.305181
# 22       have   337    0.004482    0.309663
# 23         an   335    0.004456    0.314119
# 24        new   334    0.004442    0.318561
# 25       year   329    0.004376    0.322937
# 26    compani   324    0.004309    0.327246
# 27        say   310    0.004123    0.331369
# 28        but   309    0.004110    0.335479
# 29         he   303    0.004030    0.339509
# ..        ...   ...         ...         ...
# 170     peopl    62    0.000825    0.543819
# 171   current    61    0.000811    0.544630
# 172     octob    61    0.000811    0.545441
# 173       get    61    0.000811    0.546253
# 174      rose    61    0.000811    0.547064
# 175     those    61    0.000811    0.547875
# 176    common    60    0.000798    0.548673
# 177      bill    60    0.000798    0.549471
# 178     money    60    0.000798    0.550269
# 179       net    59    0.000785    0.551054
# 180   purchas    59    0.000785    0.551839
# 181      earn    58    0.000771    0.552610
# 182   problem    58    0.000771    0.553382
# 183     gener    58    0.000771    0.554153
# 184   concern    58    0.000771    0.554925
# 185    intern    58    0.000771    0.555696
# 186      down    57    0.000758    0.556454
# 187      want    57    0.000758    0.557212
# 188  chairman    57    0.000758    0.557970
# 189    declin    56    0.000745    0.558715
# 190      work    56    0.000745    0.559460
# 191  institut    56    0.000745    0.560205
# 192       yen    56    0.000745    0.560950
# 193     right    56    0.000745    0.561694
# 194      good    56    0.000745    0.562439
# 195      sinc    56    0.000745    0.563184
# 196    trader    56    0.000745    0.563929
# 197      made    56    0.000745    0.564674
# 198     court    55    0.000732    0.565405
# 199       pay    55    0.000732    0.566137
#
# [200 rows x 4 columns]

# %% [markdown]
# 5. Create a graph that shows the relative frequency of these 200 words.

# %%
top200[['word', 'proportion']].plot.line()

# %% [markdown]
# 6. Does the observed relative frequency of these words follow Zipf’s law? Explain.

# %%
top200[['word', 'cumulative']].plot.line()

# %% [markdown]
# 7. In what ways do you think the frequency of the words in this corpus differ from “all words in all corpora.”

# %%
from nltk.corpus import stopwords
stemmed_stop_words = set(stemmer.stem(word) for word in stopwords.words('english'))

[word for word in top200.word if word not in stemmed_stop_words]
# Out:
# ['said',
#  'million',
#  'new',
#  'year',
#  'compani',
#  'say',
#  'trade',
#  'market',
#  'stock',
#  'share',
#  'would',
#  'price',
#  'program',
#  'presid',
#  'also',
#  'one',
#  'billion',
#  'bank',
#  'rate',
#  'could',
#  'fund',
#  'manag',
#  'first',
#  'issu',
#  'report',
#  'investor',
#  'two',
#  'offer',
#  'york',
#  'sale',
#  'last',
#  'make',
#  'month',
#  'execut',
#  'plan',
#  'mani',
#  'recent',
#  'use',
#  'futur',
#  'busi',
#  'invest',
#  'industri',
#  'time',
#  'profit',
#  'japanes',
#  'bond',
#  'expect',
#  'increas',
#  'govern',
#  'oper',
#  'like',
#  'close',
#  'includ',
#  'may',
#  'even',
#  'ad',
#  'group',
#  'product',
#  'feder',
#  'firm',
#  'week',
#  'take',
#  'buy',
#  'index',
#  'offici',
#  'exchang',
#  'cent',
#  'american',
#  'japan',
#  'day',
#  'board',
#  'nation',
#  'interest',
#  'big',
#  'depart',
#  'research',
#  'test',
#  'secur',
#  'hous',
#  'note',
#  'countri',
#  'next',
#  'help',
#  'yesterday',
#  'continu',
#  'unit',
#  'servic',
#  'state',
#  'analyst',
#  'end',
#  'contract',
#  'point',
#  'sell',
#  'financi',
#  'gain',
#  'much',
#  'offic',
#  'order',
#  'yield',
#  'peopl',
#  'current',
#  'octob',
#  'get',
#  'rose',
#  'common',
#  'bill',
#  'money',
#  'net',
#  'purchas',
#  'earn',
#  'problem',
#  'gener',
#  'concern',
#  'intern',
#  'want',
#  'chairman',
#  'declin',
#  'work',
#  'institut',
#  'yen',
#  'right',
#  'good',
#  'sinc',
#  'trader',
#  'made',
#  'court',
#  'pay']
